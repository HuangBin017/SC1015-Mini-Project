# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
phishdata = pd.read_csv('C:/Users/Avantika/Downloads/selected_dataset.csv')
phishdata.shape
# Out:
# (15420, 12)

# %%
phishdata.head()
# Out:
#                                                  url  total_of_www  \
# 0     http://www.progarchives.com/album.asp?id=61737             1
# 1  http://signin.eday.co.uk.ws.edayisapi.dllsign....             0
# 2  http://www.avevaconstruction.com/blesstool/ima...             1
# 3                              http://www.jp519.com/             1
# 4                       https://www.velocidrone.com/             1
#
#    longest_word_path  phish_hints  nb_hyperlinks  ratio_extHyperlinks  \
# 0                  5            0            143             0.069930
# 1                  0            2              0             0.000000
# 2                  9            0              3             0.000000
# 3                  0            0            404             0.037129
# 4                  0            0             57             0.315789
#
#    links_in_tags  safe_anchor  domain_age  google_index  page_rank      status
# ...

# %%
phishdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  15420 non-null  object
#  1   total_of_www         15420 non-null  int64
#  2   longest_word_path    15420 non-null  int64
#  3   phish_hints          15420 non-null  int64
#  4   nb_hyperlinks        15420 non-null  int64
#  5   ratio_extHyperlinks  15420 non-null  float64
#  6   links_in_tags        15420 non-null  float64
#  7   safe_anchor          15420 non-null  float64
#  8   domain_age           15420 non-null  int64
#  9   google_index         15420 non-null  int64
#  10  page_rank            15420 non-null  int64
#  11  status               15420 non-null  object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 1.4+ MB

# %%
phishdata.describe()
# Out:
#        total_of_www  longest_word_path   phish_hints  nb_hyperlinks  \
# count  15420.000000       15420.000000  15420.000000   15420.000000
# mean       0.461414           9.752140      0.302075      92.826913
# std        0.502671          21.365398      0.801489     176.234459
# min        0.000000           0.000000      0.000000       0.000000
# 25%        0.000000           0.000000      0.000000      10.000000
# 50%        0.000000           7.000000      0.000000      37.000000
# 75%        1.000000          10.000000      0.000000     108.000000
# max        2.000000         829.000000      7.000000    4659.000000
#
#        ratio_extHyperlinks  links_in_tags   safe_anchor    domain_age  \
# count         15420.000000   15420.000000  15420.000000  15420.000000
# mean              0.289352      51.066544     36.485900   4877.121855
# std               0.323609      41.132796     38.375207   2791.852359
# min               0.000000       0.000000      0.000000      0.000000
# ...

# %%
numData = pd.DataFrame(phishdata[["longest_word_path", "nb_hyperlinks", "ratio_extHyperlinks", "links_in_tags", "safe_anchor", "domain_age"]])

# %%
numData.describe()
# Out:
#        longest_word_path  nb_hyperlinks  ratio_extHyperlinks  links_in_tags  \
# count       15420.000000   15420.000000         15420.000000   15420.000000
# mean            9.752140      92.826913             0.289352      51.066544
# std            21.365398     176.234459             0.323609      41.132796
# min             0.000000       0.000000             0.000000       0.000000
# 25%             0.000000      10.000000             0.005348       0.000000
# 50%             7.000000      37.000000             0.144068      57.894737
# 75%            10.000000     108.000000             0.500000      94.444444
# max           829.000000    4659.000000             1.000000     100.000000
#
#         safe_anchor    domain_age
# count  15420.000000  15420.000000
# mean      36.485900   4877.121855
# std       38.375207   2791.852359
# min        0.000000      0.000000
# 25%        0.000000   2442.000000
# 50%       23.076923   5158.000000
# 75%       72.222222   7295.000000
# ...

# %%
f, axes = plt.subplots(6, 3, figsize=(24, 24))

count = 0

for var in numData:
    sb.boxplot(data = numData[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numData[var], ax = axes[count,1])
    sb.violinplot(data = numData[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
print(numData.corr())

# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(10, 10))
sb.heatmap(numData.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
#                      longest_word_path  nb_hyperlinks  ratio_extHyperlinks  \
# longest_word_path             1.000000      -0.067080             0.016481
# nb_hyperlinks                -0.067080       1.000000            -0.125798
# ratio_extHyperlinks           0.016481      -0.125798             1.000000
# links_in_tags                -0.021506       0.191484            -0.482576
# safe_anchor                  -0.027049       0.219425            -0.247347
# domain_age                   -0.033426       0.173251             0.110110
#
#                      links_in_tags  safe_anchor  domain_age
# longest_word_path        -0.021506    -0.027049   -0.033426
# nb_hyperlinks             0.191484     0.219425    0.173251
# ratio_extHyperlinks      -0.482576    -0.247347    0.110110
# links_in_tags             1.000000     0.369179   -0.044114
# safe_anchor               0.369179     1.000000    0.032058
# domain_age               -0.044114     0.032058    1.000000
# <Axes: >

# %%
catData = pd.DataFrame(phishdata[["google_index", "page_rank"]])

# %%
catData.describe()
# Out:
#        google_index     page_rank
# count  15420.000000  15420.000000
# mean       0.512646      3.473800
# std        0.499856      2.542771
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        1.000000      4.000000
# 75%        1.000000      5.000000
# max        1.000000     10.000000

# %%
catData["google_index"].value_counts()
# Out:
# google_index
# 1    7905
# 0    7515
# Name: count, dtype: int64

# %%
sb.catplot(y = "google_index", data = catData, kind = "count", 
           height = 8)
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
catData["page_rank"].value_counts()
# Out:
# page_rank
# 5     3135
# 0     2990
# 2     1976
# 4     1936
# 3     1664
# 6     1087
# 1      925
# 7      818
# 10     450
# 8      421
# 9       18
# Name: count, dtype: int64

# %%
sb.catplot(y = "page_rank", data = catData, kind = "count", 
           height = 8)
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(data= phishdata,
                  y_vars=["phish_hints"],
                  x_vars=["longest_word_path", "nb_hyperlinks", "ratio_extHyperlinks", "links_in_tags", "safe_anchor", "domain_age"])
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(data= phishdata,
                  y_vars=["google_index"],
                  x_vars=["longest_word_path", "nb_hyperlinks", "ratio_extHyperlinks", "links_in_tags", "safe_anchor", "domain_age"])
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(data= phishdata,
                  y_vars=["page_rank"],
                  x_vars=["longest_word_path", "nb_hyperlinks", "ratio_extHyperlinks", "links_in_tags", "safe_anchor", "domain_age"])
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(data = numData)
# Out:
# C:\Users\Avantika\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.boxplot(x="google_index", y="page_rank", data=catData)
# Out:
# <Axes: xlabel='google_index', ylabel='page_rank'>
